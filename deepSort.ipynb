# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 28.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.21.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/ZQPei/deep_sort_pytorch.git
# Out:
# Cloning into 'deep_sort_pytorch'...
# remote: Enumerating objects: 732, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 732 (delta 8), reused 5 (delta 0), pack-reused 717
# Receiving objects: 100% (732/732), 23.72 MiB | 11.26 MiB/s, done.
# Resolving deltas: 100% (355/355), done.

# %%
# %cd deep_sort_pytorch/
# Out:
# /workspaces/DeepSort-Tutorial/deep_sort_pytorch

# %%
# !pip install -r requirements.txt
# Out:
# Collecting atomicwrites==1.3.0
#   Downloading atomicwrites-1.3.0-py2.py3-none-any.whl (5.9 kB)
# Collecting attrs==19.3.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting colorama==0.4.3
#   Downloading colorama-0.4.3-py2.py3-none-any.whl (15 kB)
# Collecting easydict==1.9
#   Downloading easydict-1.9.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting entrypoints==0.3
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting et-xmlfile==1.0.1
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting flake8==3.7.9
#   Downloading flake8-3.7.9-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 2.1 MB/s eta 0:00:00
# Collecting flake8-import-order==0.18.1
#   Downloading flake8_import_order-0.18.1-py2.py3-none-any.whl (15 kB)
# Collecting importlib-metadata==1.6.0
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting jdcal==1.4.1
#   Downloading jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Collecting joblib==0.14.1
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Collecting numpy==1.18.2
#   Downloading numpy-1.18.2-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 25.7 MB/s eta 0:00:0000:0100:01
# Collecting lap==0.4.0
#   Downloading lap-0.4.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 20.8 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting mccabe==0.6.1
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting more-itertools==8.2.0
#   Downloading more_itertools-8.2.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.9 MB/s eta 0:00:00
# Collecting motmetrics==1.2.0
#   Downloading motmetrics-1.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 6.8 MB/s eta 0:00:00
# Collecting opencv-python==4.2.0.34
#   Downloading opencv_python-4.2.0.34-cp37-cp37m-manylinux1_x86_64.whl (28.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 6.7 MB/s eta 0:00:00:00:0100:01
# Collecting openpyxl==3.0.3
#   Downloading openpyxl-3.0.3.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.8/172.8 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting packaging==20.3
#   Downloading packaging-20.3-py2.py3-none-any.whl (37 kB)
# Collecting pandas==1.0.3
#   Downloading pandas-1.0.3-cp37-cp37m-manylinux1_x86_64.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 17.3 MB/s eta 0:00:0000:010:01
# Collecting Pillow==8.3.2
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.9 MB/s eta 0:00:0000:01
# Collecting pluggy==0.13.1
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting py==1.10.0
#   Downloading py-1.10.0-py2.py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 5.0 MB/s eta 0:00:00
# Collecting py-cpuinfo==5.0.0
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycodestyle==2.5.0
#   Downloading pycodestyle-2.5.0-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 2.4 MB/s eta 0:00:00
# Collecting pyflakes==2.1.1
#   Downloading pyflakes-2.1.1-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 1.8 MB/s eta 0:00:00
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.4 MB/s eta 0:00:00
# Collecting pytest==5.4.1
#   Downloading pytest-5.4.1-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 kB 7.9 MB/s eta 0:00:00
# Collecting pytest-benchmark==3.2.3
#   Downloading pytest_benchmark-3.2.3-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 2.3 MB/s eta 0:00:00
# Collecting python-dateutil==2.8.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.2/227.2 kB 9.8 MB/s eta 0:00:00
# Collecting pytz==2019.3
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 18.1 MB/s eta 0:00:00
# Collecting PyYAML==5.4
#   Downloading PyYAML-5.4-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.5/636.5 kB 16.0 MB/s eta 0:00:00
# Collecting scikit-learn==0.22.2.post1
#   Downloading scikit_learn-0.22.2.post1-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 12.8 MB/s eta 0:00:0000:0100:01
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 11.7 MB/s eta 0:00:0000:0100:01
# Collecting six==1.14.0
#   Downloading six-1.14.0-py2.py3-none-any.whl (10 kB)
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch==1.4.0
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.4/753.4 MB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.5.0
#   Downloading torchvision-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 30.8 MB/s eta 0:00:0000:01:00:01
# Collecting Vizer==0.1.5
#   Downloading Vizer-0.1.5.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting wcwidth==0.1.9
#   Downloading wcwidth-0.1.9-py2.py3-none-any.whl (19 kB)
# Collecting xmltodict==0.12.0
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting zipp==3.1.0
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: setuptools in /workspaces/DeepSort-Tutorial/env/lib/python3.7/site-packages (from flake8-import-order==0.18.1->-r requirements.txt (line 8)) (65.6.3)
# Building wheels for collected packages: easydict, et-xmlfile, lap, openpyxl, py-cpuinfo, sklearn, Vizer
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6344 sha256=982524c5721a6a5f57222688526303a91a45fc33aec6c1a553ca4181cf5f3171
#   Stored in directory: /home/codespace/.cache/pip/wheels/8c/4a/18/dd5a489c6250a3ff8be47ddcbb90636091ee543655ddb1969f
#   Building wheel for et-xmlfile (setup.py) ... done
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8898 sha256=f2c527942f99afe10bdaadf525d6badd6dc297d0d21edcb9136c919435b86e89
#   Stored in directory: /home/codespace/.cache/pip/wheels/57/fd/96/1edce869253e2148e8f4168d9a444b5e918c6001d794537a44
#   Building wheel for lap (setup.py) ... done
#   Created wheel for lap: filename=lap-0.4.0-cp37-cp37m-linux_x86_64.whl size=1655053 sha256=71fc4f47bf1f1615e37f34b9f21051541d75afefd5cffe6c7b3dfb1969108337
#   Stored in directory: /home/codespace/.cache/pip/wheels/6b/d3/9e/e501dc5f1f813505db98dfb89a766c4039ca6df4dbc99321c7
#   Building wheel for openpyxl (setup.py) ... done
#   Created wheel for openpyxl: filename=openpyxl-3.0.3-py2.py3-none-any.whl size=241263 sha256=0c7216421b50f6ca031e7167d98c42ad58b02a60a4dc8ed19fc7f573a74604c2
#   Stored in directory: /home/codespace/.cache/pip/wheels/7a/01/f4/0445117c0f38bbafd4a4a022826533bc62151b40e6f158481a
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18678 sha256=ddfdb537a326b008dda968b302c8cede24b08269ee3eb154e2e0c8b042c85ff9
#   Stored in directory: /home/codespace/.cache/pip/wheels/44/f8/0b/67cf5f46ce760c46b54d01a96d6b73b51c74d189ee8d28e84f
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1302 sha256=32563e0a90690b810b67f9e831d51ad978899e443d232383d31ee9d8fd545967
#   Stored in directory: /home/codespace/.cache/pip/wheels/f5/d9/b2/a9d58f54cfa2235cb19895aeb4e5d8488667c0536c7248f212
#   Building wheel for Vizer (setup.py) ... done
#   Created wheel for Vizer: filename=Vizer-0.1.5-py3-none-any.whl size=3482 sha256=287a09d05a1e2b2ee4db665341c9642929a2280b4ded28f1c78bf0342c486365
#   Stored in directory: /home/codespace/.cache/pip/wheels/65/01/8b/e0ad343422f64b81c0193ee71d399d884f851b7995022ae699
# Successfully built easydict et-xmlfile lap openpyxl py-cpuinfo sklearn Vizer
# Installing collected packages: wcwidth, pytz, py-cpuinfo, mccabe, lap, joblib, jdcal, et-xmlfile, easydict, zipp, xmltodict, torch, six, PyYAML, pyparsing, pyflakes, pycodestyle, py, Pillow, openpyxl, numpy, more-itertools, entrypoints, colorama, attrs, atomicwrites, torchvision, scipy, python-dateutil, packaging, opencv-python, importlib-metadata, flake8-import-order, flake8, Vizer, scikit-learn, pluggy, pandas, sklearn, pytest, pytest-benchmark, motmetrics
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.10
#     Uninstalling wcwidth-0.2.10:
#       Successfully uninstalled wcwidth-0.2.10
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.4
#     Uninstalling entrypoints-0.4:
#       Successfully uninstalled entrypoints-0.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0
#     Uninstalling python-dateutil-2.9.0:
#       Successfully uninstalled python-dateutil-2.9.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-client 7.4.9 requires python-dateutil>=2.8.2, but you have python-dateutil 2.8.1 which is incompatible.
# Successfully installed Pillow-8.3.2 PyYAML-5.4 Vizer-0.1.5 atomicwrites-1.3.0 attrs-19.3.0 colorama-0.4.3 easydict-1.9 entrypoints-0.3 et-xmlfile-1.0.1 flake8-3.7.9 flake8-import-order-0.18.1 importlib-metadata-1.6.0 jdcal-1.4.1 joblib-0.14.1 lap-0.4.0 mccabe-0.6.1 more-itertools-8.2.0 motmetrics-1.2.0 numpy-1.18.2 opencv-python-4.2.0.34 openpyxl-3.0.3 packaging-20.3 pandas-1.0.3 pluggy-0.13.1 py-1.10.0 py-cpuinfo-5.0.0 pycodestyle-2.5.0 pyflakes-2.1.1 pyparsing-2.4.7 pytest-5.4.1 pytest-benchmark-3.2.3 python-dateutil-2.8.1 pytz-2019.3 scikit-learn-0.22.2.post1 scipy-1.4.1 six-1.14.0 sklearn-0.0 torch-1.4.0 torchvision-0.5.0 wcwidth-0.1.9 xmltodict-0.12.0 zipp-3.1.0

# %%
pwd
# Out:
# '/workspaces/DeepSort-Tutorial/deep_sort_pytorch'

# %%
# %cd deep_sort/deep
# Out:
# /workspaces/DeepSort-Tutorial/deep_sort_pytorch/deep_sort/deep

# %%
# %cp -r /workspaces/DeepSort-Tutorial/data /workspaces/DeepSort-Tutorial/deep_sort_pytorch/deep_sort/deep/

# %%
# !python train.py
# Out:
# Epoch : 1
# Testing ...
# [progress:100.0%]time:1.73s Loss:0.00000 Correct:22/22 Acc:100.000%
# Saving parameters to checkpoint/ckpt.t7
#
# Epoch : 2
# Testing ...
# [progress:100.0%]time:1.65s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 3
# Testing ...
# [progress:100.0%]time:1.29s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 4
# Testing ...
# [progress:100.0%]time:1.53s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 5
# Testing ...
# [progress:100.0%]time:1.47s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 6
# Testing ...
# [progress:100.0%]time:1.61s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 7
# Testing ...
# [progress:100.0%]time:2.11s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 8
# Testing ...
# [progress:100.0%]time:1.18s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 9
# Testing ...
# [progress:100.0%]time:1.60s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 10
# Testing ...
# [progress:100.0%]time:1.42s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 11
# Testing ...
# [progress:100.0%]time:1.48s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 12
# Testing ...
# [progress:100.0%]time:0.77s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 13
# Testing ...
# [progress:100.0%]time:0.79s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 14
# Testing ...
# [progress:100.0%]time:0.75s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 15
# Testing ...
# [progress:100.0%]time:0.71s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 16
# Testing ...
# [progress:100.0%]time:0.71s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 17
# Testing ...
# [progress:100.0%]time:0.73s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 18
# Testing ...
# [progress:100.0%]time:0.89s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 19
# Testing ...
# [progress:100.0%]time:0.70s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 20
# Testing ...
# [progress:100.0%]time:0.71s Loss:0.00000 Correct:22/22 Acc:100.000%
# Learning rate adjusted to 0.010000000000000002
#
# Epoch : 21
# Testing ...
# [progress:100.0%]time:0.71s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 22
# Testing ...
# [progress:100.0%]time:0.77s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 23
# Testing ...
# [progress:100.0%]time:0.74s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 24
# Testing ...
# [progress:100.0%]time:0.77s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 25
# Testing ...
# [progress:100.0%]time:0.78s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 26
# Testing ...
# [progress:100.0%]time:0.70s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 27
# Testing ...
# [progress:100.0%]time:0.77s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 28
# Testing ...
# [progress:100.0%]time:0.69s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 29
# Testing ...
# [progress:100.0%]time:0.72s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 30
# Testing ...
# [progress:100.0%]time:0.78s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 31
# Testing ...
# [progress:100.0%]time:0.75s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 32
# Testing ...
# [progress:100.0%]time:0.75s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 33
# Testing ...
# [progress:100.0%]time:0.75s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 34
# Testing ...
# [progress:100.0%]time:0.76s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 35
# Testing ...
# [progress:100.0%]time:0.71s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 36
# Testing ...
# [progress:100.0%]time:0.77s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 37
# Testing ...
# [progress:100.0%]time:0.77s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 38
# Testing ...
# [progress:100.0%]time:0.93s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 39
# Testing ...
# [progress:100.0%]time:0.73s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 40
# Testing ...
# [progress:100.0%]time:0.72s Loss:0.00000 Correct:22/22 Acc:100.000%
# Learning rate adjusted to 0.0010000000000000002
